# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
"""Run Gdrive mount tests"""
import os

folder_path = '/content/drive/MyDrive/project/AEGIS/data'

# Check if the directory exists
if os.path.exists(folder_path):
    # List all entries in the directory
    entries = os.listdir(folder_path)

    # Filter out only directories
    subfolders = [entry for entry in entries if os.path.isdir(os.path.join(folder_path, entry))]

    if subfolders:
        print(f"'{folder_path}' 아래의 하위 폴더 목록:")
        for folder in subfolders:
            print(f"{folder}")
    else:
        print(f"'{folder_path}' 아래에 하위 폴더가 없습니다.")
else:
    print(f"경로 '{folder_path}'를 찾을 수 없습니다.")
# Out:
# '/content/drive/MyDrive/project/AEGIS/data' 아래의 하위 폴더 목록:
# 폭행(Assault)
# 절도(Burglary)
# 파손(Vandalism)
# 실신(Swoon)
# 침입(Trespass)
# 투기(Dump)
# 방화(arson)
# 강도(Robbery)
# 173.공원 주요시설 및 불법행위 감시 CCTV 영상 데이터
# 이상행동 CCTV 영상
# 미사용_흡연(smoke)

# %%
import os

folder_path = '/content/drive/MyDrive/project/AEGIS/Dataset/burglary/실내'

# Check if the directory exists
if os.path.exists(folder_path):
    # List all entries in the directory
    entries = os.listdir(folder_path)

    # Filter out only files
    files_in_folder = [entry for entry in entries if os.path.isfile(os.path.join(folder_path, entry))]

    if files_in_folder:
        # sorted_files = sorted(files_in_folder, reverse=True)
        sorted_files = sorted(files_in_folder)

        print(f"'{folder_path}' 아래의 파일 목록:")
        print(f"{len(files_in_folder)}개")

        # for file_name in files_in_folder:
        for file_name in sorted_files:
            print(f"{file_name}")
    else:
        print(f"'{folder_path}' 아래에 파일이 없습니다.")
else:
    print(f"경로 '{folder_path}'를 찾을 수 없습니다.")

# %%
# !pip install --upgrade pip
# !pip install notion-client

# %%
"""Run Notion tests"""
from test_notion import (
    test_notion_connection,
    test_database_schema,
    test_read_specific_columns,
    test_read_all_data,
)

print("\n" + "="*60)
print("Notion API Test Suite")
print("="*60)

# Test 1: Connection
reader = test_notion_connection()
if not reader:
    print("\n❌ Tests failed: Could not connect to Notion")
    # return

# Test 2: Schema
test_database_schema(reader)

# Test 3: Specific columns (columns 이름 test_notion.py에 하드코딩 됨)
test_read_specific_columns(reader)

# Test 4: All data
test_read_all_data(reader)

print("\n" + "="*60)
print("✅ All tests completed!")
print("="*60)
# Out:
# ============================================================
# Notion API Test Suite
# ============================================================
# ============================================================
# Test 1: Notion Connection
# ============================================================
# ✅ Settings validation passed
# ✅ NotionTableReader created successfully
#
# ============================================================
# Test 2: Database Schema
# ============================================================
# Database: 절도_실내_DB_예시
# Database ID: 295b90665b0a80c599e3cd7e87de0b34
#
# Properties:
# ------------------------------------------------------------
#   memo_2                         | Type: rich_text
#   abnormal_end_1                 | Type: number
#   memo_1                         | Type: rich_text
#   abnormal_start_1               | Type: number
#   URL                            | Type: url
#   suspicious_end                 | Type: number
#   abnormal_start_2               | Type: number
#   suspicious_start               | Type: number
#   abnormal_end_2                 | Type: number
#   filename                       | Type: title
# ------------------------------------------------------------
#
# ✅ Schema retrieved successfully
#
# ============================================================
# Test 3: Reading specific Columns
# ============================================================
# AttributeError: 'DatabasesEndpoint' object has no attribute 'query'. Trying alternative approach...
# [DEBUG] First result keys: dict_keys(['object', 'id', 'created_time', 'last_edited_time', 'created_by', 'last_edited_by', 'cover', 'icon', 'parent', 'archived', 'in_trash', 'is_locked', 'properties', 'url', 'public_url'])
# [DEBUG] First result properties: {'memo_2': {'id': 'Lf%5ER', 'type': 'rich_text', 'rich_text': []}, 'abnormal_end_1': {'id': 'P%5Ez%3E', 'type': 'number', 'number': None}, 'memo_1': {'id': '%5BCKO', 'type': 'rich_text', 'rich_text': []}, 'abnormal_start_1': {'id': '%5BRii', 'type': 'number', 'number': None}, 'URL': {'id': 'cX%7D%3A', 'type': 'url', 'url': None}, 'suspicious_end': {'id': 'f%60%3DG', 'type': 'number', 'number': None}, 'abnormal_start_2': {'id': 'mER%3E', 'type': 'number', 'number': None}, 'suspicious_start': {'id': 'nFOF', 'type': 'number', 'number': None}, 'abnormal_end_2': {'id': 'zlAc', 'type': 'number', 'number': None}, 'filename': {'id': 'title', 'type': 'title', 'title': []}}
#
# 총 51개의 행을 읽어왔습니다.
#
# 데이터가 있는 행: 5개
#
# ------------------------------------------------------------
# Row 1:
#   filename: C_3_12_41_BU_DYA_07-29_15-20-29_CF_RGB_DF2_F2.mp4
#
#   suspicious_start: None
#   suspicious_end: None
# ------------------------------------------------------------
# Row 2:
#   filename: C_3_12_40_BU_SMC_10-14_11-43-44_CE_RGB_DF2_M2.mp4
#   suspicious_start: None
#   suspicious_end: None
# ------------------------------------------------------------
# Row 3:
#   filename: C_3_12_40_BU_SMC_10-14_11-43-44_CD_RGB_DF2_M2.mp4
#   suspicious_start: 16
#   suspicious_end: 24
# ------------------------------------------------------------
# Row 4:
#   filename: C_3_12_41_BU_DYA_07-29_15-20-29_CE_RGB_DF2_F2.mp4
#   suspicious_start: None
#   suspicious_end: None
# ------------------------------------------------------------
# Row 5:
#   filename: C_3_12_41_BU_DYA_07-29_15-20-29_CD_RGB_DF2_F2.mp4
#   suspicious_start: None
#   suspicious_end: None
# ------------------------------------------------------------
#
# ✅ Successfully read 51 rows
#
# ============================================================
# Test 4: Reading All Data
# ============================================================
# AttributeError: 'DatabasesEndpoint' object has no attribute 'query'. Trying alternative approach...
# [DEBUG] First result keys: dict_keys(['object', 'id', 'created_time', 'last_edited_time', 'created_by', 'last_edited_by', 'cover', 'icon', 'parent', 'archived', 'in_trash', 'is_locked', 'properties', 'url', 'public_url'])
# [DEBUG] First result properties: {'memo_2': {'id': 'Lf%5ER', 'type': 'rich_text', 'rich_text': []}, 'abnormal_end_1': {'id': 'P%5Ez%3E', 'type': 'number', 'number': None}, 'memo_1': {'id': '%5BCKO', 'type': 'rich_text', 'rich_text': []}, 'abnormal_start_1': {'id': '%5BRii', 'type': 'number', 'number': None}, 'URL': {'id': 'cX%7D%3A', 'type': 'url', 'url': None}, 'suspicious_end': {'id': 'f%60%3DG', 'type': 'number', 'number': None}, 'abnormal_start_2': {'id': 'mER%3E', 'type': 'number', 'number': None}, 'suspicious_start': {'id': 'nFOF', 'type': 'number', 'number': None}, 'abnormal_end_2': {'id': 'zlAc', 'type': 'number', 'number': None}, 'filename': {'id': 'title', 'type': 'title', 'title': []}}
#
# 총 51개의 행을 읽어왔습니다.
# 데이터가 있는 행: 5개
#
# --- 데이터가 있는 행들 ---
#
# Row 1:
#   memo_2: 3. burglary(절도)
#   abnormal_end_1: None
#   memo_1:
#   abnormal_start_1: None
#   URL: None
#   suspicious_end: None
#   abnormal_start_2: None
#   suspicious_start: None
#   abnormal_end_2: None
#   filename: C_3_12_41_BU_DYA_07-29_15-20-29_CF_RGB_DF2_F2.mp4
#
# ----------------------------------------
#
# Row 2:
#   memo_2: 0. swoon(실신)
#   abnormal_end_1: None
#   memo_1:
#   abnormal_start_1: None
#   URL: None
#   suspicious_end: None
#   abnormal_start_2: None
#   suspicious_start: None
#   abnormal_end_2: None
#   filename: C_3_12_40_BU_SMC_10-14_11-43-44_CE_RGB_DF2_M2.mp4
# ----------------------------------------
#
# Row 3:
#   memo_2: 2차 구분)
#   abnormal_end_1: 60
#   memo_1:
#   abnormal_start_1: 25
#   URL: https://drive.google.com/open?id=1VccuBJkMImRzsBRc7AE_y2yqs53EyAaZ&usp=drive_copy
#   suspicious_end: 24
#   abnormal_start_2: None
#   suspicious_start: 16
#   abnormal_end_2: None
#   filename: C_3_12_40_BU_SMC_10-14_11-43-44_CD_RGB_DF2_M2.mp4
# ----------------------------------------
#
# Row 4:
#   memo_2: 2. assault(폭행)
#   abnormal_end_1: None
#   memo_1:
#   abnormal_start_1: None
#   URL: None
#   suspicious_end: None
#   abnormal_start_2: None
#   suspicious_start: None
#   abnormal_end_2: None
#   filename: C_3_12_41_BU_DYA_07-29_15-20-29_CE_RGB_DF2_F2.mp4
# ----------------------------------------
#
# Row 5:
#   memo_2: 1. vandalism(파손)
#   abnormal_end_1: None
#   memo_1:
#   abnormal_start_1: None
#   URL: None
#   suspicious_end: None
#   abnormal_start_2: None
#   suspicious_start: None
#   abnormal_end_2: None
#   filename: C_3_12_41_BU_DYA_07-29_15-20-29_CD_RGB_DF2_F2.mp4
# ----------------------------------------
#
# ✅ Successfully read all data
#
# ============================================================
# ✅ All tests completed!
# ============================================================
